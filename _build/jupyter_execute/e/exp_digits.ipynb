# %% [markdown]
# # Цифры числа $e$

# %% [markdown]
# ## Число $e$ на калькуляторе

# %% [markdown]
# Когда я учился в школе, моей любимый игрушкой был инженерный калькулятор. Его табло вмещало $10$ цифр, и число $e$ на нём выглядело вот так:
#
# <img width="200px" src="../images/calc_e.jpg" alt="euler_number" class="bg-primary mb-1" align="center">
#
# ```{admonition} Любопытный факт
# :class: tip
# По забавному совпадению цифр число $e$ имеет прозвище **«два и семь, два Толстых»**, ведь 1828 — год рождения [Льва Толстого](https://ru.wikipedia.org/wiki/%D0%A2%D0%BE%D0%BB%D1%81%D1%82%D0%BE%D0%B9,_%D0%9B%D0%B5%D0%B2_%D0%9D%D0%B8%D0%BA%D0%BE%D0%BB%D0%B0%D0%B5%D0%B2%D0%B8%D1%87).
#
# <img width="500px" src="../images/e_tolstoy.jpg" alt="2*tolstoy" align="center">
# ```

# %% [markdown]
# ## Намёк на рациональность

# %% [markdown]
# Там, где два Толстых, вполне могло бы случиться и три, и четыре, и вообще бесконечное их количество. В последнем случае число $e$ оказалось бы **периодической десятичной дробью**
#
# ```{math}
# :label: e-rational
# e \stackrel{?}{=} 2.7182818281828\ldots \equiv 2.7(1828)
# ```
#
# Если равенство {eq}`e-rational` верно, то число $e$ должно быть **рациональным**. Это прямое следствие следующей теоремы:
#
# ````{prf:theorem}
# :label: rational-decimal
# :nonumber:
#
# Всякая периодическая десятичная дробь является рациональным числом, то есть может быть записана в виде отношения двух целых чисел.
# ````

# %% [markdown]
# Вот несколько примеров превращения периодической десятичной дроби в обыкновенную:
# * $0.166666\ldots \equiv 0.1(6) = \frac 16$
# * $2.363636\ldots \equiv 2.(36) = \frac {26}{11}$
# * $-1.25 \equiv -1.25(0) = -\frac 54$
# * $3.142857142857\ldots \equiv 3.(142857) = 3 + \frac 17 = \frac{22}7$
#
# ```{admonition} Как происходят такие превращения?
# :class: note, dropdown
#
# Возьмём для примера периодическую дробь $x = 2.(36)$. Выделим целую часть:
#
# $$
# x = 2 + y,\quad y = 0.(36).
# $$
#
#
# Чтобы найти $y$, домножим его на $100 = 10^2$ (десять в степени длина периода). Получаем
#
# $$
#     100 y = 36.(36) = 36 + 0.(36) = 36 + y.
# $$
#
# Из этого уравнения находим, что
#
# $$
#     y = \frac{36}{100 - 1} = \frac{36}{99} = \frac{4}{11},
#  $$
#
# и поэтому $x = 2 + y = 2\frac 4{11} = \frac{26}{11}$.
# ```
#
# <span style="display:none" id="q_e_rational">...</span>
#
# <span style="display:none" id="q_dec2frac">...</span>

# %%
from jupyterquiz import display_quiz
quiz = display_quiz("#q_dec2frac")
# Out:
# <div id="WTJLIEzfAfWJ" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #WTJLIEzfAfWJ {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %% [markdown]
# ```{hint}
# :class: dropdown
# Записав $2.7(18) = 2.7 + 0.1x$, выразите $100x$ через $x$.
# ```

# %%
import random

N = 10
for i in range(N):
    random_number = "{:.9f}".format(random.random())
    print(f"number={random_number}, 2—5: {random_number[3:7]}, 6—9: {random_number[7:]}")
# Out:
# number=0.343153383, 2—5: 4315, 6—9: 3383
# number=0.220935017, 2—5: 2093, 6—9: 5017
# number=0.992073581, 2—5: 9207, 6—9: 3581
# number=0.227523012, 2—5: 2752, 6—9: 3012
# number=0.868459340, 2—5: 6845, 6—9: 9340
# number=0.788370122, 2—5: 8837, 6—9: 0122
# number=0.102095384, 2—5: 0209, 6—9: 5384
# number=0.032103646, 2—5: 3210, 6—9: 3646
# number=0.785365951, 2—5: 8536, 6—9: 5951
# number=0.828596348, 2—5: 2859, 6—9: 6348

# %%
import random

def lucky_numbers(attempts):
    c = 0
    for i in range(attempts):
        random_number = "{:.9f}".format(random.random())
        if random_number[3:7] == random_number[7:]:
            c += 1
    print(f"Счастливыми оказались: {c} из {attempts}")

lucky_numbers(10**6)
# Out:
# Счастливыми оказались: 105 из 1000000

# %% [markdown]
# ## Число $e$ на компьютере

# %% [markdown]
# Так совпало, что на калькуляторе с десятью разрядами число $e$ смахивает на периодическую десятичную дробь {eq}`e-rational`. Однако если вооружиться калькулятором побольше или компьютером, то таких иллюзий не возникнет. Вот как выглядят $16$ первых цифр числа $e$:

# %%
import math 
print(math.e)
# Out:
# 2.718281828459045

# %% [markdown]
# Дополнительные к двум Толстым 6 цифр образуют углы равнобедренного прямоугольного треугольника, что позволяет немного расширить мнемоническое правило для запоминания цифр числа $e$:
#
# <img width="400px" src="../images/e_mnemonic.jpg" alt="euler_mnemonic" class="bg-primary mb-1" align="center">

# %% [markdown]
# ```{warning}
# Разумеется, даже этими цифрами число $e$ не исчерпывается. Скоро мы [докажем](e-irr-label), что число $e$ иррационально, а это означает, что
# * $е \ne \frac mn$ ни при каких целых числах $m$ и $n$;
# * $e = \overline{a_0.a_1a_2\ldots a_n \ldots}$ — бесконечная непериодическая десятичная дробь.
# ```
#
# <span style="display:none" id="q_e_decimal_series">...</span>

# %%
display_quiz("#q_e_decimal_series", max_width=660)
# Out:
# <div id="dolxYbawiRWc" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="660"
#                style="border-radius: 10px; text-align: left"> <style>
# #dolxYbawiRWc {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %% [markdown]
# Компьютеры используют стандартный тип **double** для записи десятичных дробей, который обычно позволяет хранить только $16$ цифр после десятичной точки. Если же использовать библиотеку [decimal](https://docs.python.org/3/library/decimal.html) языка Python, то можно раздобыть сколько душе угодно[^digits-mem] верных десятичных знаков числа $e$. Например, $100$:
#
# [^digits-mem]: Лишь бы хватило оперативы

# %%
from decimal import Decimal, getcontext
getcontext().prec=100
print(Decimal.exp(Decimal(1)))
# Out:
# 2.718281828459045235360287471352662497757247093699959574966967627724076630353547594571382178525166427

# %%
Decimal(28245729/10391023), Decimal(410105312/150869313), Decimal(14665106/5394991)
# Out:
# (Decimal('2.718281828459045978974017998552881181240081787109375'),
#  Decimal('2.718281828459045090795598298427648842334747314453125'),
#  Decimal('2.718281828459028215405623996048234403133392333984375'))

# %% [markdown]
# <img width = "500px" src="https://blog.reface.ai/content/images/2021/04/0_Mi-xBLF3U-58Eu76.png" align="center">

# %% [markdown]
# Вычисление верных десятичных знаков знаменитых иррациональных чисел, таких как $\pi$, $e$, $\sqrt 2$, $\varphi = \frac {\sqrt 5 - 1}2$ (золотое сечение), представляет собой своеобразный вид спорта. Первоначальные вехи на этом пути в отношении числа $e$ перечислены в следующей таблице из [википедии](https://en.wikipedia.org/wiki/E_(mathematical_constant)#Known_digits):
#
# <img width="500px" src="../images/e_decimals.png" alt="euler_decimals" class="bg-primary mb-1" align="center">
#
# Далее резко возросшая вычислительная мощность компьютеров позволила вычислять миллионы, миллиарды и даже триллионы цифр числа $e$. На [конец 2020 года](http://www.numberworld.org/digits/E/) рекорд составляет свыше $31$ триллиона десятичных знаков.
#
# <span style="display:none" id="q_e_trillions">...</span>

# %%
display_quiz("#q_e_trillions")
# Out:
# <div id="WzchxYiCecIY" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #WzchxYiCecIY {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %% [markdown]
# ## Десятичные приближения числа $e$

# %% [markdown]
# Чем больше цифр взять, тем точнее получится приближение к истинному значению числа $e$: обрубая бесконечную десятичную дробь
#
# $$
#    e = \overline{2.71828\ldots a_{n-1} a_n \ldots},
# $$
#
# после $a_{n-1}$, получаем конечную десятичную дробь
#
# $$
# e_n = \overline{2.71828\ldots a_{n-1}}, \quad e \approx e_n.
# $$
#
# Погрешность такого приближения равна
#
# $$
# r_n = e - e_n = \overline{\underbrace{0.00\ldots 0}_{n\text{ нулей}} a_n \ldots} = \frac{a_n}{10^n} + \frac{a_{n+1}}{10^{n+1}} + \ldots
# $$
#
# Это заведомо меньше, чем
#
# $$
#     \underbrace{0.00\ldots 0}_{n\text{ нулей}} (9) = \underbrace{0.00\ldots 0}_{n - 1\text{ нуль}}1 = \frac 1{10^{n-1}}.
# $$
#
# ```{admonition} Вывод
# :class: note
# Если взять приближение числа $e$, содержащее $n$ его верных десятичных знаков (включая целую часть), то погрешность приближения $r_n$ удовлетворяет неравенству $0 \leqslant r_n \leqslant \frac 1{10^{n-1}}$.
# ```

# %% [markdown]
# <span style="display:none" id="q_e_approx">...</span>

# %%
display_quiz("#q_e_approx", num=1)
# Out:
# <div id="kkJfUrCcRpsE" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #kkJfUrCcRpsE {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
# ...

# %% [markdown]
# ## Задачи
#
# 1. Запишите число {eq}`e-rational` в виде несократимой дроби $\frac mn$.
#
# 2. Назовём число *счастливым*, если в десятичной записи оно имеет одинаковые четвёрки цифр на позициях со 2-й по 5-ю и с 6-й по 9-ю после десятичной точки:
#
#     $$
#         \ldots\bullet.\bullet abcdabcd\bullet\ldots
#     $$
#
#     Например, число $e$ счастливое. Какова вероятность того, что наугад взятое число счастливое?
#
# 3. Рекорд [2020 года](http://www.numberworld.org/digits/E/) содержит $31\,415\,926\,535\,897$ верных десятичных знаков числа $e$. Что за странное число? Почему именно столько?
#
# 4. Докажите равенство
# $\underbrace{0.00\ldots 0}_{n\text{ нулей}} (9) = \underbrace{0.00\ldots 0}_{n - 1\text{ нуль}}1.$
#
# 5. 💻 Число $\alpha \in \mathbb R$ называется *нормальным*, если в его десятичной записи все $10$ цифр встречаются в равной пропорции, т.е. доля каждой составляет $10\%$ (в математике это называется **равномерное распределение**). Подсчитайте, сколько раз встречается каждая цифра в первых $100$, $1000$, $10000$ десятичных знаках числа $e$. Похоже ли, что число $e$ нормальное?
